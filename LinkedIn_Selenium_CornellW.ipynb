# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from parsel import Selector
import pandas as pd
import numpy as np
import time
EXE_PATH = r"C:\Users\19145\Downloads\chromedriver_win32\chromedriver.exe"
driver = webdriver.Chrome(executable_path=EXE_PATH)

# %%
driver.get('https://www.linkedin.com')

# %%
driver.find_element_by_class_name("input")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d6b1efd0ea8fba86559e2e9399ff39c6", element="69177228-3d5c-4333-9fcc-9c34eb67e7c4")>

# %%
driver.find_element_by_name("session_key")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d6b1efd0ea8fba86559e2e9399ff39c6", element="47e211f3-6ceb-45d2-b95f-14e00d572c90")>

# %%
username = driver.find_element_by_name("session_key")
username.send_keys('eric.cruz.4242@gmail.com')

# %%
driver.find_element_by_name("session_password")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d6b1efd0ea8fba86559e2e9399ff39c6", element="aa3c56ed-1e0b-418e-8464-db5348ec44d4")>

# %%
password = driver.find_element_by_name("session_password")
password.send_keys('Cassidy1!')

# %%
driver.find_element_by_class_name("sign-in-form__footer")
log_in_button = driver.find_element_by_class_name("sign-in-form__submit-btn")
log_in_button.click()

# %%
driver.find_element_by_class_name("search-global-typeahead__input.always-show-placeholder")
searchname = driver.find_element_by_class_name("search-global-typeahead__input.always-show-placeholder")

# %%
searchname.send_keys('Eric Cruz Cornell')

# %%
driver.find_element_by_class_name("search-global-typeahead__controls")
clicksearch = driver.find_element_by_class_name("search-global-typeahead__controls")
clicksearch.click()
time.sleep(10)

# %%
driver.find_element_by_xpath('//span[@class="name actor-name"]').click()
time.sleep(1)

# %%
searchresult=[]
name=[]
LName=[]
headline=[]
location=[]
company=[]
school=[]
activities=[]

# %%
searchresult = driver.current_url
searchresult
time.sleep(1)

# %%
sel=Selector(text=driver.page_source)
name = sel.xpath('//*[starts-with(@class, "inline t-24")]/text()').extract_first()
name = name.strip()
LName = name
#time.sleep(5)
#name.append(name)
headline = sel.xpath('//*[starts-with(@class, "mt1 t-18")]/text()').extract_first()
headline = headline.strip()
#time.sleep(5)
#headline.append(headline)
location = sel.xpath('//*[starts-with(@class, "t-16")]/text()').extract_first()
location = location.strip()
time.sleep(5)
#location.append(location)
company = sel.xpath('//*[starts-with(@class, "pv-entity__secondary-title")]/text()').extract_first()
if company is None:
    company = "Not Found"
company = company.strip()
#time.sleep(5)
#company.append(company)
school = sel.xpath('//*[starts-with(@class, "pv-entity__school-name")]/text()').getall()
#school.append(school)
#time.sleep(5)
activities = sel.xpath('//*[starts-with(@class, "activities-societies")]/text()').getall()
#activities.append(activities)
#time.sleep(5)

# %%
df = pd.DataFrame({
'Name':[name],
'LName':[LName],    
'SearchResult':[searchresult], 
'Headline':[headline], 
'Location':[location], 
'Company':[company],
'School':[school],
'Activites':[activities]    
})

# %%
df
# Out:
#         Name      LName                                     SearchResult  \
# 0  Eric Cruz  Eric Cruz  https://www.linkedin.com/in/eric-cruz-07124651/
#
#                         Headline                Location    Company School  \
# 0  Finance | IT | Data Science |  New Rochelle, New York  Not Found     []
#
#   Activites
# 0        []

# %%
namelist = pd.read_csv('NameListCornellW.csv')
names = pd.read_csv('NameListCornellW.csv')
companies = pd.read_csv('CriteriaListCornellW.csv')
names = pd.DataFrame(names).to_numpy()
companies = pd.DataFrame(companies).to_numpy()

# %%
query = []
Name = []
for name, company in zip(names, companies): 
    Name = name
    query = name + company
    searchname.send_keys(query)
    driver.find_element_by_class_name("search-global-typeahead__controls")
    clicksearch = driver.find_element_by_class_name("search-global-typeahead__controls")
    clicksearch.click()
    time.sleep(1)
    try:
        driver.find_element_by_xpath('//span[@class="name actor-name"]').click()
        time.sleep(2)
        searchresult = driver.current_url
    except Exception:
        print(query)
        driver.find_element_by_class_name("search-global-typeahead__input.always-show-placeholder")
        searchname = driver.find_element_by_class_name("search-global-typeahead__input.always-show-placeholder")        
        searchname.clear()
        time.sleep(1)
        driver.find_element_by_class_name("search-global-typeahead__controls")
        clicksearch = driver.find_element_by_class_name("search-global-typeahead__controls")
        clicksearch.click()
        time.sleep(2)
        clicksearch.click()
    else:
        sel=Selector(text=driver.page_source)
        name = sel.xpath('//*[starts-with(@class, "inline t-24")]/text()').extract_first()
        if name is None:
            name = "Not Found"
        LName = name.strip()
#time.sleep(5)
        headline = sel.xpath('//*[starts-with(@class, "mt1 t-18")]/text()').extract_first()
        if headline is None:
            headline = "Not Found"
        headline = headline.strip()
#time.sleep(5)
        location = sel.xpath('//*[starts-with(@class, "t-16")]/text()').extract_first()
        if location is None:
            location = "Not Found"
        location = location.strip()
        time.sleep(2)
        company = sel.xpath('//*[starts-with(@class, "pv-entity__secondary-title")]/text()').extract_first()
        if company is None:
            company = "Not Found"
        company = company.strip()
#time.sleep(5)
        school = sel.xpath('//*[starts-with(@class, "pv-entity__school-name")]/text()').getall()
#time.sleep(5)
        activities = sel.xpath('//*[starts-with(@class, "activities-societies")]/text()').getall()
#time.sleep(5)
        tempdf = pd.DataFrame({
        'Name':[Name], 
        'LName' :[LName],
        'SearchResult':[searchresult], 
        'Headline':[headline], 
        'Location':[location], 
        'Company':[company],
        'School':[school],
        'Activites':[activities]    
        })
        df=df.append(tempdf)

# %%
names
# Out:
# array([['Megan Polnet'],
#        ['Valerie Ho'],
#        ['Katherine Nguyen'],
#        ['Khary Pryce'],
#        ['Maria Adiaconitei'],
#        ['Ana Elhom']], dtype=object)

# %%
namelist
# Out:
#                 name
# 0       Megan Polnet
# 1         Valerie Ho
# 2   Katherine Nguyen
# 3        Khary Pryce
# 4  Maria Adiaconitei
# 5          Ana Elhom

# %%
Name = []

# %%
namelist[0:1]
# Out:
#            name
# 0  Megan Polnet

# %%
df
# Out:
#                   Name              LName  \
# 0            Eric Cruz          Eric Cruz
# 0                 name       Megan Polnet
# 0                 name       Megan Polnet
# 0       [Megan Polnet]       Megan Polnet
# 0         [Valerie Ho]         Valerie Ho
# 0   [Katherine Nguyen]   Katherine Nguyen
# 0        [Khary Pryce]        Khary Pryce
# 0  [Maria Adiaconitei]  Maria Adiaconitei
# 0          [Ana Elhom]          Ana Elhom

# 0  [Varsity Tennis Team, Big Red Leadership Insti...
# 0  [Varsity Tennis Team, Big Red Leadership Insti...
# 0  [Cornell Club Tennis Vice President | Cornell ...

# %%
df.tail()
# Out:
#    Name              LName                                       SearchResult  \
# 0  None         Valerie Ho            https://www.linkedin.com/in/valeriehho/
# 0  None   Katherine Nguyen  https://www.linkedin.com/in/katherine-nguyen-b...
# 0  None        Khary Pryce  https://www.linkedin.com/in/khary-pryce-543470...
# 0  None  Maria Adiaconitei  https://www.linkedin.com/in/maria-adiaconitei-...
# 0  None          Ana Elhom   https://www.linkedin.com/in/ana-elhom-671565156/
#
#                                             Headline  \
# 0              Student-Athlete at Cornell University
# 0              Student-Athlete at Cornell University
# 0  Peer Facilitator  at Intergroup Dialogue Proje...
# 0                      Student at Cornell University
# 0      Incoming Technical Operations Intern at Merck
#
#                      Location                                      Company  \
# 0  Washington D.C. Metro Area                                       Sodexo
# 0    Greater Los Angeles Area                         SmartyPants Vitamins
# 0       Albany, New York Area                           Cornell University
# 0       Ithaca, New York Area  Washington Orthopaedics and Sports Medicine
# 0  Washington D.C. Metro Area                                        Merck
#
#                                               School  \
# 0  [Cornell University, Montgomery Blair High Sch...
# 0  [Cornell University, Fountain Valley High School]
# 0  [Cornell University, IMG Academy, McDonogh Sch...
# 0                               [Cornell University]
# 0            [Cornell University, The Bullis School]
#
#                                            Activites
# 0  [Varsity Women's Tennis, Big Red Leadership In...
# 0  [Cornell Varsity Women's Tennis Team, Big Red ...
# 0  [Varsity Tennis Team, Big Red Leadership Insti...
# 0  [Varsity Tennis Team, Big Red Leadership Insti...
# 0  [Cornell Club Tennis Vice President | Cornell ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 0 to 0
# Data columns (total 8 columns):
# Name            202 non-null object
# LName           202 non-null object
# SearchResult    202 non-null object
# Headline        202 non-null object
# Location        202 non-null object
# Company         202 non-null object
# School          202 non-null object
# Activites       202 non-null object
# dtypes: object(8)
# memory usage: 14.2+ KB

# %%
df.describe()
# Out:
#                    Name                             LName  \
# count               202                               202
# unique              202                               200
# top     [Elena Bennett]  Robert Brassell, Jr., N.Y.S.N.P.
# freq                  1                                 2
#
#                                              SearchResult  \
# count                                                 202
# unique                                                200
# top     https://www.linkedin.com/in/paulina-raguz-mack...
# freq                                                    2
#
#                              Headline                    Location    Company  \
# count                             202                         202        202
# unique                            194                         109        147
# top     Student at Cornell University  Greater New York City Area  Not Found
# freq                                5                          34         42
#
#        School Activites
# count     202       202
# unique    132        86
# top        []        []
# freq       42       116

# %%
df.isnull().sum()
# Out:
# Name            0
# LName           0
# SearchResult    0
# Headline        0
# Location        0
# Company         0
# School          0
# Activites       0
# dtype: int64

# %%
df["School"].value_counts()
# Out:
# []                                                                                                         42
# [Cornell University]                                                                                       28
# [Columbia University - Graduate School of Journalism, Cornell University]                                   2
# [Cornell University, Hillcrest Secondary School]                                                            2
# [Emerson College, TEFL Institute]                                                                           1
#                                                                                                            ..
# [Joan & Sanford I. Weill Medical College of Cornell University, Fordham University, Cornell University]     1
# [Cornell University, Nanuet Senior High School, Yale-New Haven Hospital]                                    1
# [Boston University School of Law, Cornell University]                                                       1
# [Cornell University, New Trier]                                                                             1
# [Cornell University, University of Pennsylvania]                                                            1
# Name: School, Length: 132, dtype: int64

# %%
#df.School.unique()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Name', 'LName', 'SearchResult', 'Headline', 'Location', 'Company',
#        'School', 'Activites'],
#       dtype='object')

# %%
df.to_csv("CornellWomenLinkedIn.csv", index=False)
